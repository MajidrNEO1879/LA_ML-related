# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("../content/sample_data/Zomato-data-.csv")
df.head(100)
# Out:
#                           name online_order book_table   rate  votes  \
# 0                        Jalsa          Yes        Yes  4.1/5    775
# 1               Spice Elephant          Yes         No  4.1/5    787
# 2              San Churro Cafe          Yes         No  3.8/5    918
# 3        Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4                Grand Village           No         No  3.8/5    166
# ..                         ...          ...        ...    ...    ...
# 95  Vi Ra's Bar and Restaurant           No         No  3.3/5     62
# 96                      Kaggis           No         No  3.8/5     64
# 97        Ayda Persian Kitchen           No         No  3.7/5     39
# 98                Chatar Patar           No         No  3.7/5     65
# 99                  Polar Bear          Yes         No  3.8/5     71
#
#     approx_cost(for two people) listed_in(type)
# 0                           800          Buffet
# ...

# %%
df['rate'] = df['rate'].str.replace(' ', '/', regex=False)
df['rate'] = df['rate'].str.split('/').str[0]
df['rate'] = df['rate'].astype(float)
df
# Out:
#                       name online_order book_table  rate  votes  \
# 0                    Jalsa          Yes        Yes  4.15    775
# 1           Spice Elephant          Yes         No  4.15    787
# 2          San Churro Cafe          Yes         No  3.85    918
# 3    Addhuri Udupi Bhojana           No         No  3.75     88
# 4            Grand Village           No         No  3.85    166
# ..                     ...          ...        ...   ...    ...
# 143       Melting Melodies           No         No  3.35      0
# 144        New Indraprasta           No         No  3.35      0
# 145           Anna Kuteera          Yes         No  4.05    771
# 146                 Darbar           No         No  3.05     98
# 147          Vijayalakshmi          Yes         No  3.95     47
#
#      approx_cost(for two people) listed_in(type)
# 0                            800          Buffet
# 1                            800          Buffet
# ...

# %%
yes_count = (df['online_order'] == 'Yes').sum()
no_count = (df['online_order'] == 'No').sum()
plt.bar(['Yes', 'No'], [yes_count, no_count], color=['green', 'red'])
plt.xlabel("Online Order")
plt.ylabel("Count")
plt.title("Order Histogram")
plt.show()

# %%
din_num = 0;
buffet_num = 0;
Cafes_num = 0;
others = 0;
for i in df['listed_in(type)']:
  if i == "Dining":
    din_num += 1;
  elif i == "Buffet":
    buffet_num += 1;
  elif i == "Cafes":
    Cafes_num += 1;
  else:
    others +=1;
din_num
# Out:
# 110

# %%
plt.bar(['Buffet', 'Others', 'Cafe', 'Dining'], [buffet_num,others, Cafes_num,din_num])
plt.show()

# %%
rating_counts = df['approx_cost(for two people)'].value_counts().sort_index()
plt.bar(rating_counts.index, rating_counts.values, color='blue')
plt.xlabel("Rating")
plt.ylabel("Count")
plt.title("Rating Distribution")
plt.show()
